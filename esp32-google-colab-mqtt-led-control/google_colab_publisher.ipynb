# %%
# !pip install paho-mqtt
# Out:
# Requirement already satisfied: paho-mqtt in /usr/local/lib/python3.12/dist-packages (2.1.0)

# %%
import paho.mqtt.client as mqtt

broker = "broker.hivemq.com"
topic = "home/led"

client = mqtt.Client()

client.connect(broker, 1883)

print("Connected to MQTT Broker!")
# Out:
# Connected to MQTT Broker!
# /tmp/ipykernel_2058/966957861.py:6: DeprecationWarning: Callback API version 1 is deprecated, update to latest version
#   client = mqtt.Client()

# %%
client.publish(topic, "ON")
print("LED ON command sent")
# Out:
# LED ON command sent

# %%
client.publish(topic, "OFF")
print("LED OFF command sent")
# Out:
# LED OFF command sent
